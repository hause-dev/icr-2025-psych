# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.datasets import make_blobs
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
# Load in your data here
data = pd.read_csv("AEIanxietyhc_allPSD.csv") #file name here
print(data.shape[1])
print(data.shape[1])
print(data.iloc[:,117])
# Out:
# 118
# 118
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 194    0
# 195    0
# 196    0
# 197    0
# 198    0
# Name: Class, Length: 199, dtype: int64

# %%
bands = [
    ('Delta', data.iloc[:, list(range(0,22))+[-1]]),
    ('Theta', data.iloc[:, list(range(0,3)) + list(range(22,41))+[-1]]),
    ('Alpha', data.iloc[:, list(range(0,3)) + list(range(41,60))+[-1]]),
    ('Beta', data.iloc[:, list(range(0,3)) + list(range(60,79))+[-1]]),
    ('HighBeta', data.iloc[:, list(range(0,3)) + list(range(79,98))+[-1]]),
    ('Gamma', data.iloc[:, list(range(0,3)) + list(range(98,117))+[-1]]),
    ('All', data.iloc[:, 0:118])
]
all_model_data = []

#bands = [delta, theta, alpha, beta, highbeta, gamma, allb]

for label, band in bands:
    # Data preprocessing
    print(f"\n{label} columns:\n", band.columns.tolist())
    X = band.drop('Class', axis=1)
    y = band['Class']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, stratify=None)
    pca = PCA(0.95)
    X_pca = pca.fit_transform(X)
    X_pca.shape
    X = X.dropna()
    X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.1, random_state=30)
    svclassifier = SVC(kernel='linear',probability=True)
    svclassifier.fit(X_train, y_train)
    y_pred = svclassifier.predict(X_test)
    print('SVM accuracy:', svclassifier.score(X_test, y_test))
    print('SVM classification report:\n', classification_report(y_test, y_pred))
    y_scores = svclassifier.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    # Calculate AUC
    svm_auc = auc(fpr, tpr)
    print('SVM AUC value:', svm_auc)
    newsvm=SVC(kernel='linear', probability=True)
    newsvm.fit(X_train_pca, y_train)
    y_pred = newsvm.predict(X_test_pca)
    print('\nSVM accuracy for PCA:', newsvm.score(X_test_pca, y_test))
    print('SVM classification report for PCA:\n', classification_report(y_test, y_pred))
    y_scores = newsvm.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pcasvm_auc = auc(fpr, tpr)
    print('SVM AUC value for PCA:', pcasvm_auc)
    
    knn = KNeighborsClassifier(n_neighbors=10)
    knn.fit(X_train, y_train)
    print('KNN accuracy:', knn.score(X_test, y_test))
    y_pred = knn.predict(X_test)
    print('KNN classification report:\n',classification_report(y_test, y_pred))
    y_scores = knn.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    knn_auc = auc(fpr, tpr)
    print('KNN AUC value:', knn_auc)
    pknn = KNeighborsClassifier(n_neighbors=10)
    pknn.fit(X_train_pca, y_train)
    print('\nKNN accuracy for PCA:', pknn.score(X_test_pca, y_test))
    y_pred = pknn.predict(X_test_pca)
    print('KNN classification report for PCA\n', classification_report(y_test, y_pred))
    y_scores = pknn.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pcaknn_auc = auc(fpr, tpr)
    print('KNN AUC value for PCA',pcaknn_auc)
    
    model = RandomForestClassifier(n_estimators=40)
    model.fit(X_train, y_train)
    print('Random Forest accuracy:', model.score(X_test, y_test))
    y_pred = model.predict(X_test)
    print('Random Forest classification report\n',classification_report(y_test, y_pred))
    y_scores = model.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    rf_auc = auc(fpr, tpr)
    print('Random Forest AUC value:', rf_auc)
    pmodel = RandomForestClassifier(n_estimators=40)
    pmodel.fit(X_train_pca, y_train)
    print('\nRandom Forest accuracy for PCA:', pmodel.score(X_test_pca, y_test))
    y_pred = pmodel.predict(X_test_pca)
    print('Random Forest classification report for PCA:\n',classification_report(y_test, y_pred))
    y_scores = pmodel.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pcarf_auc = auc(fpr, tpr)
    print('Random Forest AUC value for PCA:', pcarf_auc)
    
    lg = LogisticRegression()
    lg.fit(X_train, y_train)
    print('Logistic Regression accuracy:', lg.score(X_test, y_test))
    y_pred = lg.predict(X_test)
    print('Logistic Regression classification report:\n',classification_report(y_test, y_pred))
    y_scores = lg.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    lg_auc = auc(fpr, tpr)
    print('Logistic Regression AUC value:',lg_auc)
    plg = LogisticRegression()
    plg.fit(X_train_pca, y_train)
    print('\nLogistic Regression accuracy for PCA:',plg.score(X_test_pca, y_test))
    y_pred = plg.predict(X_test_pca)
    print('Logistic Regression classification report for PCA:\n',classification_report(y_test, y_pred))
    y_scores = plg.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pcalg_auc = auc(fpr, tpr)
    print('Logistic Regression AUC value for PCA',pcalg_auc)
    
    clf = xgb.XGBClassifier(tree_method="hist", early_stopping_rounds=2)
    clf.fit(X_train, y_train, eval_set=[(X_test, y_test)])
    y_pred = clf.predict(X_test)
    print('XGB accuracy:',clf.score(X_test, y_test))
    print('XGB Classification report:\n',classification_report(y_test, y_pred))
    y_scores = clf.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    xgb_auc = auc(fpr, tpr)
    print('XGB AUC value:',xgb_auc)
    pxgb = xgb.XGBClassifier(tree_method="hist", early_stopping_rounds=2)
    pxgb.fit(X_train_pca, y_train, eval_set=[(X_test_pca, y_test)])
    print('\nXGB accuracy for PCA:', pxgb.score(X_test_pca, y_test))
    y_pred = pxgb.predict(X_test_pca)
    print('XGB classification report for PCA:\n',classification_report(y_test, y_pred))
    y_scores = pxgb.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pxgb_auc = auc(fpr, tpr)
    print('XBG AUC for PCA:', pxgb_auc)
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    model_row = [
        f"Anxiety+AEI_{label}_PSD",
        svclassifier.score(X_test, y_test), svm_auc,
        knn.score(X_test, y_test), knn_auc,
        model.score(X_test, y_test), rf_auc,
        lg.score(X_test, y_test), lg_auc,
        clf.score(X_test, y_test), xgb_auc
    ]
    pca_row = [
        f"Anxiety+AEI_{label}_PSDPCA", 
        newsvm.score(X_test_pca, y_test), pcasvm_auc,
        pknn.score(X_test_pca, y_test),pcaknn_auc,
        pmodel.score(X_test_pca, y_test),pcarf_auc,
        plg.score(X_test_pca, y_test),pcalg_auc,
        pxgb.score(X_test_pca, y_test), pxgb_auc
    ]
    all_model_data.append(model_row)
    all_model_data.append(pca_row)
    for row in all_model_data:
        print(row, type(row), len(row) if hasattr(row, '__len__') else 'Not iterable')
columns = ['Combination', 'SVM Accuracy', 'SVM AUC', 
           'KNN Accuracy', 'KNN AUC', 
           'Random Forest Accuracy','Random Forest AUC', 
           'Logistic Regression Accuracy', 'Logistic Regression AUC', 
           'XGB Accuracy', 'XGB AUC']
    
df = pd.DataFrame(all_model_data, columns=columns)
df.to_csv('masterdata.csv', index=False)
# Out:
# Delta columns:
#  ['age', 'education', 'IQ', 'AB.A.delta.a.FP1', 'AB.A.delta.b.FP2', 'AB.A.delta.c.F7', 'AB.A.delta.d.F3', 'AB.A.delta.e.Fz', 'AB.A.delta.f.F4', 'AB.A.delta.g.F8', 'AB.A.delta.h.T3', 'AB.A.delta.i.C3', 'AB.A.delta.j.Cz', 'AB.A.delta.k.C4', 'AB.A.delta.l.T4', 'AB.A.delta.m.T5', 'AB.A.delta.n.P3', 'AB.A.delta.o.Pz', 'AB.A.delta.p.P4', 'AB.A.delta.q.T6', 'AB.A.delta.r.O1', 'AB.A.delta.s.O2', 'Class']
# SVM accuracy: 0.475
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.44      0.20      0.28        20
#            1       0.48      0.75      0.59        20
#
#     accuracy                           0.47        40
#    macro avg       0.46      0.47      0.43        40
# weighted avg       0.46      0.47      0.43        40
#
# SVM AUC value: 0.51
#
# SVM accuracy for PCA: 0.775
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78        20
#            1       0.79      0.75      0.77        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# SVM AUC value for PCA: 0.87
# KNN accuracy: 0.475
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.48      0.65      0.55        20
#            1       0.46      0.30      0.36        20
#
#     accuracy                           0.47        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# KNN AUC value: 0.545
#
# KNN accuracy for PCA: 0.75
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        20
#            1       0.78      0.70      0.74        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# KNN AUC value for PCA 0.8075000000000001
# Random Forest accuracy: 0.525
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.53      0.50      0.51        20
#            1       0.52      0.55      0.54        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# Random Forest AUC value: 0.545
#
# Random Forest accuracy for PCA: 0.775
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.82      0.70      0.76        20
#            1       0.74      0.85      0.79        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.77      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# Random Forest AUC value for PCA: 0.7875
# Logistic Regression accuracy: 0.45
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.30      0.35        20
#            1       0.46      0.60      0.52        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# Logistic Regression AUC value: 0.5025
#
# Logistic Regression accuracy for PCA: 0.775
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78        20
#            1       0.79      0.75      0.77        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# Logistic Regression AUC value for PCA 0.8524999999999999
# [0]	validation_0-logloss:0.65323
# [1]	validation_0-logloss:0.66159
# [2]	validation_0-logloss:0.67946
# XGB accuracy: 0.7
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.55      0.65        20
#            1       0.65      0.85      0.74        20
#
#     accuracy                           0.70        40
#    macro avg       0.72      0.70      0.69        40
# weighted avg       0.72      0.70      0.69        40
#
# XGB AUC value: 0.64625
# [0]	validation_0-logloss:0.58921
# [1]	validation_0-logloss:0.54114
# [2]	validation_0-logloss:0.53879
# [3]	validation_0-logloss:0.55414
# [4]	validation_0-logloss:0.54360
#
# XGB accuracy for PCA: 0.775
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.76      0.80      0.78        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# XBG AUC for PCA: 0.8275
# [[15  5]
#  [ 4 16]]
# ['Anxiety+AEI_Delta_PSD', 0.475, 0.51, 0.475, 0.545, 0.525, 0.545, 0.45, 0.5025, 0.7, 0.64625] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.775, 0.87, 0.75, 0.8075000000000001, 0.775, 0.7875, 0.775, 0.8524999999999999, 0.775, 0.8275] <class 'list'> 11
#
# Theta columns:
#  ['age', 'education', 'IQ', 'AB.B.theta.a.FP1', 'AB.B.theta.b.FP2', 'AB.B.theta.c.F7', 'AB.B.theta.d.F3', 'AB.B.theta.e.Fz', 'AB.B.theta.f.F4', 'AB.B.theta.g.F8', 'AB.B.theta.h.T3', 'AB.B.theta.i.C3', 'AB.B.theta.j.Cz', 'AB.B.theta.k.C4', 'AB.B.theta.l.T4', 'AB.B.theta.m.T5', 'AB.B.theta.n.P3', 'AB.B.theta.o.Pz', 'AB.B.theta.p.P4', 'AB.B.theta.q.T6', 'AB.B.theta.r.O1', 'AB.B.theta.s.O2', 'Class']
# SVM accuracy: 0.675
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.50      0.61        20
#            1       0.63      0.85      0.72        20
#
#     accuracy                           0.68        40
#    macro avg       0.70      0.68      0.66        40
# weighted avg       0.70      0.68      0.66        40
#
# SVM AUC value: 0.6000000000000001
#
# SVM accuracy for PCA: 0.725
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.76      0.65      0.70        20
#            1       0.70      0.80      0.74        20
#
#     accuracy                           0.72        40
#    macro avg       0.73      0.73      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# SVM AUC value for PCA: 0.8225
# KNN accuracy: 0.475
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.48      0.55      0.51        20
#            1       0.47      0.40      0.43        20
#
#     accuracy                           0.47        40
#    macro avg       0.47      0.48      0.47        40
# weighted avg       0.47      0.47      0.47        40
#
# KNN AUC value: 0.53
#
# KNN accuracy for PCA: 0.675
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.67      0.70      0.68        20
#            1       0.68      0.65      0.67        20
#
#     accuracy                           0.68        40
#    macro avg       0.68      0.68      0.67        40
# weighted avg       0.68      0.68      0.67        40
#
# KNN AUC value for PCA 0.775
# Random Forest accuracy: 0.5
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.50      0.45      0.47        20
#            1       0.50      0.55      0.52        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.50        40
# weighted avg       0.50      0.50      0.50        40
#
# Random Forest AUC value: 0.48625
#
# Random Forest accuracy for PCA: 0.675
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.73      0.55      0.63        20
#            1       0.64      0.80      0.71        20
#
#     accuracy                           0.68        40
#    macro avg       0.69      0.68      0.67        40
# weighted avg       0.69      0.68      0.67        40
#
# Random Forest AUC value for PCA: 0.84125
# Logistic Regression accuracy: 0.7
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.55      0.65        20
#            1       0.65      0.85      0.74        20
#
#     accuracy                           0.70        40
#    macro avg       0.72      0.70      0.69        40
# weighted avg       0.72      0.70      0.69        40
#
# Logistic Regression AUC value: 0.5974999999999999
#
# Logistic Regression accuracy for PCA: 0.75
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        20
#            1       0.73      0.80      0.76        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# Logistic Regression AUC value for PCA 0.83
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0]	validation_0-logloss:0.73811
# [1]	validation_0-logloss:0.76002
# XGB accuracy: 0.35
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        20
#            1       0.41      0.70      0.52        20
#
#     accuracy                           0.35        40
#    macro avg       0.21      0.35      0.26        40
# weighted avg       0.21      0.35      0.26        40
#
# XGB AUC value: 0.41125
# [0]	validation_0-logloss:0.61296
# [1]	validation_0-logloss:0.57807
# [2]	validation_0-logloss:0.52845
# [3]	validation_0-logloss:0.51279
# [4]	validation_0-logloss:0.50632
# [5]	validation_0-logloss:0.48510
# [6]	validation_0-logloss:0.48615
# [7]	validation_0-logloss:0.49500
#
# XGB accuracy for PCA: 0.7
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        20
#            1       0.70      0.70      0.70        20
#
#     accuracy                           0.70        40
#    macro avg       0.70      0.70      0.70        40
# weighted avg       0.70      0.70      0.70        40
#
# XBG AUC for PCA: 0.85
# [[14  6]
#  [ 6 14]]
# ['Anxiety+AEI_Delta_PSD', 0.475, 0.51, 0.475, 0.545, 0.525, 0.545, 0.45, 0.5025, 0.7, 0.64625] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.775, 0.87, 0.75, 0.8075000000000001, 0.775, 0.7875, 0.775, 0.8524999999999999, 0.775, 0.8275] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.675, 0.6000000000000001, 0.475, 0.53, 0.5, 0.48625, 0.7, 0.5974999999999999, 0.35, 0.41125] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.725, 0.8225, 0.675, 0.775, 0.675, 0.84125, 0.75, 0.83, 0.7, 0.85] <class 'list'> 11
#
# Alpha columns:
#  ['age', 'education', 'IQ', 'AB.C.alpha.a.FP1', 'AB.C.alpha.b.FP2', 'AB.C.alpha.c.F7', 'AB.C.alpha.d.F3', 'AB.C.alpha.e.Fz', 'AB.C.alpha.f.F4', 'AB.C.alpha.g.F8', 'AB.C.alpha.h.T3', 'AB.C.alpha.i.C3', 'AB.C.alpha.j.Cz', 'AB.C.alpha.k.C4', 'AB.C.alpha.l.T4', 'AB.C.alpha.m.T5', 'AB.C.alpha.n.P3', 'AB.C.alpha.o.Pz', 'AB.C.alpha.p.P4', 'AB.C.alpha.q.T6', 'AB.C.alpha.r.O1', 'AB.C.alpha.s.O2', 'Class']
# SVM accuracy: 0.475
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.46      0.30      0.36        20
#            1       0.48      0.65      0.55        20
#
#     accuracy                           0.47        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# SVM AUC value: 0.49249999999999994
#
# SVM accuracy for PCA: 0.7
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        20
#            1       0.70      0.70      0.70        20
#
#     accuracy                           0.70        40
#    macro avg       0.70      0.70      0.70        40
# weighted avg       0.70      0.70      0.70        40
#
# SVM AUC value for PCA: 0.81125
# KNN accuracy: 0.525
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.65      0.58        20
#            1       0.53      0.40      0.46        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# KNN AUC value: 0.5075000000000001
#
# KNN accuracy for PCA: 0.725
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.71      0.75      0.73        20
#            1       0.74      0.70      0.72        20
#
#     accuracy                           0.72        40
#    macro avg       0.73      0.72      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# KNN AUC value for PCA 0.8049999999999999
# Random Forest accuracy: 0.4
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.41      0.45      0.43        20
#            1       0.39      0.35      0.37        20
#
#     accuracy                           0.40        40
#    macro avg       0.40      0.40      0.40        40
# weighted avg       0.40      0.40      0.40        40
#
# Random Forest AUC value: 0.49874999999999997
#
# Random Forest accuracy for PCA: 0.725
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72        20
#            1       0.71      0.75      0.73        20
#
#     accuracy                           0.72        40
#    macro avg       0.73      0.72      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# Random Forest AUC value for PCA: 0.7949999999999999
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression accuracy: 0.525
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.40      0.46        20
#            1       0.52      0.65      0.58        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# Logistic Regression AUC value: 0.53
#
# Logistic Regression accuracy for PCA: 0.675
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.68      0.65      0.67        20
#            1       0.67      0.70      0.68        20
#
#     accuracy                           0.68        40
#    macro avg       0.68      0.68      0.67        40
# weighted avg       0.68      0.68      0.67        40
#
# Logistic Regression AUC value for PCA 0.8049999999999999
# [0]	validation_0-logloss:0.69994
# [1]	validation_0-logloss:0.70463
# [2]	validation_0-logloss:0.70274
# XGB accuracy: 0.525
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.45      0.49        20
#            1       0.52      0.60      0.56        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# XGB AUC value: 0.5137499999999999
# [0]	validation_0-logloss:0.58814
# [1]	validation_0-logloss:0.54469
# [2]	validation_0-logloss:0.51333
# [3]	validation_0-logloss:0.49507
# [4]	validation_0-logloss:0.49435
# [5]	validation_0-logloss:0.49973
# [6]	validation_0-logloss:0.50154
#
# XGB accuracy for PCA: 0.775
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.76      0.80      0.78        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# XBG AUC for PCA: 0.8512499999999998
# [[15  5]
#  [ 4 16]]
# ['Anxiety+AEI_Delta_PSD', 0.475, 0.51, 0.475, 0.545, 0.525, 0.545, 0.45, 0.5025, 0.7, 0.64625] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.775, 0.87, 0.75, 0.8075000000000001, 0.775, 0.7875, 0.775, 0.8524999999999999, 0.775, 0.8275] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.675, 0.6000000000000001, 0.475, 0.53, 0.5, 0.48625, 0.7, 0.5974999999999999, 0.35, 0.41125] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.725, 0.8225, 0.675, 0.775, 0.675, 0.84125, 0.75, 0.83, 0.7, 0.85] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.475, 0.49249999999999994, 0.525, 0.5075000000000001, 0.4, 0.49874999999999997, 0.525, 0.53, 0.525, 0.5137499999999999] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.7, 0.81125, 0.725, 0.8049999999999999, 0.725, 0.7949999999999999, 0.675, 0.8049999999999999, 0.775, 0.8512499999999998] <class 'list'> 11
#
# Beta columns:
#  ['age', 'education', 'IQ', 'AB.D.beta.a.FP1', 'AB.D.beta.b.FP2', 'AB.D.beta.c.F7', 'AB.D.beta.d.F3', 'AB.D.beta.e.Fz', 'AB.D.beta.f.F4', 'AB.D.beta.g.F8', 'AB.D.beta.h.T3', 'AB.D.beta.i.C3', 'AB.D.beta.j.Cz', 'AB.D.beta.k.C4', 'AB.D.beta.l.T4', 'AB.D.beta.m.T5', 'AB.D.beta.n.P3', 'AB.D.beta.o.Pz', 'AB.D.beta.p.P4', 'AB.D.beta.q.T6', 'AB.D.beta.r.O1', 'AB.D.beta.s.O2', 'Class']
# SVM accuracy: 0.45
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.30      0.35        20
#            1       0.46      0.60      0.52        20
#
#     accuracy                           0.45        40
#    macro avg       0.45      0.45      0.44        40
# weighted avg       0.45      0.45      0.44        40
#
# SVM AUC value: 0.5549999999999999
#
# SVM accuracy for PCA: 0.775
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.82      0.70      0.76        20
#            1       0.74      0.85      0.79        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.77      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# SVM AUC value for PCA: 0.845
# KNN accuracy: 0.625
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.45      0.55        20
#            1       0.59      0.80      0.68        20
#
#     accuracy                           0.62        40
#    macro avg       0.64      0.62      0.61        40
# weighted avg       0.64      0.62      0.61        40
#
# KNN AUC value: 0.5625
#
# KNN accuracy for PCA: 0.8
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82        20
#            1       0.88      0.70      0.78        20
#
#     accuracy                           0.80        40
#    macro avg       0.81      0.80      0.80        40
# weighted avg       0.81      0.80      0.80        40
#
# KNN AUC value for PCA 0.81625
# Random Forest accuracy: 0.5
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.50      0.35      0.41        20
#            1       0.50      0.65      0.57        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# Random Forest AUC value: 0.4975
#
# Random Forest accuracy for PCA: 0.8
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        20
#            1       0.80      0.80      0.80        20
#
#     accuracy                           0.80        40
#    macro avg       0.80      0.80      0.80        40
# weighted avg       0.80      0.80      0.80        40
#
# Random Forest AUC value for PCA: 0.8724999999999999
# Logistic Regression accuracy: 0.45
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.42      0.25      0.31        20
#            1       0.46      0.65      0.54        20
#
#     accuracy                           0.45        40
#    macro avg       0.44      0.45      0.43        40
# weighted avg       0.44      0.45      0.43        40
#
# Logistic Regression AUC value: 0.48750000000000004
#
# Logistic Regression accuracy for PCA: 0.775
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.76      0.80      0.78        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# Logistic Regression AUC value for PCA 0.835
# [0]	validation_0-logloss:0.70143
# [1]	validation_0-logloss:0.71787
# [2]	validation_0-logloss:0.71482
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# XGB accuracy: 0.475
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.46      0.30      0.36        20
#            1       0.48      0.65      0.55        20
#
#     accuracy                           0.47        40
#    macro avg       0.47      0.47      0.46        40
# weighted avg       0.47      0.47      0.46        40
#
# XGB AUC value: 0.54125
# [0]	validation_0-logloss:0.60712
# [1]	validation_0-logloss:0.55671
# [2]	validation_0-logloss:0.54260
# [3]	validation_0-logloss:0.53067
# [4]	validation_0-logloss:0.50973
# [5]	validation_0-logloss:0.50883
# [6]	validation_0-logloss:0.49638
# [7]	validation_0-logloss:0.50312
# [8]	validation_0-logloss:0.49290
# [9]	validation_0-logloss:0.50102
# [10]	validation_0-logloss:0.50430
#
# XGB accuracy for PCA: 0.775
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.76      0.80      0.78        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# XBG AUC for PCA: 0.8612500000000001
# [[15  5]
#  [ 4 16]]
# ['Anxiety+AEI_Delta_PSD', 0.475, 0.51, 0.475, 0.545, 0.525, 0.545, 0.45, 0.5025, 0.7, 0.64625] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.775, 0.87, 0.75, 0.8075000000000001, 0.775, 0.7875, 0.775, 0.8524999999999999, 0.775, 0.8275] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.675, 0.6000000000000001, 0.475, 0.53, 0.5, 0.48625, 0.7, 0.5974999999999999, 0.35, 0.41125] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.725, 0.8225, 0.675, 0.775, 0.675, 0.84125, 0.75, 0.83, 0.7, 0.85] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.475, 0.49249999999999994, 0.525, 0.5075000000000001, 0.4, 0.49874999999999997, 0.525, 0.53, 0.525, 0.5137499999999999] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.7, 0.81125, 0.725, 0.8049999999999999, 0.725, 0.7949999999999999, 0.675, 0.8049999999999999, 0.775, 0.8512499999999998] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSD', 0.45, 0.5549999999999999, 0.625, 0.5625, 0.5, 0.4975, 0.45, 0.48750000000000004, 0.475, 0.54125] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSDPCA', 0.775, 0.845, 0.8, 0.81625, 0.8, 0.8724999999999999, 0.775, 0.835, 0.775, 0.8612500000000001] <class 'list'> 11
#
# HighBeta columns:
#  ['age', 'education', 'IQ', 'AB.E.highbeta.a.FP1', 'AB.E.highbeta.b.FP2', 'AB.E.highbeta.c.F7', 'AB.E.highbeta.d.F3', 'AB.E.highbeta.e.Fz', 'AB.E.highbeta.f.F4', 'AB.E.highbeta.g.F8', 'AB.E.highbeta.h.T3', 'AB.E.highbeta.i.C3', 'AB.E.highbeta.j.Cz', 'AB.E.highbeta.k.C4', 'AB.E.highbeta.l.T4', 'AB.E.highbeta.m.T5', 'AB.E.highbeta.n.P3', 'AB.E.highbeta.o.Pz', 'AB.E.highbeta.p.P4', 'AB.E.highbeta.q.T6', 'AB.E.highbeta.r.O1', 'AB.E.highbeta.s.O2', 'Class']
# SVM accuracy: 0.575
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.50      0.54        20
#            1       0.57      0.65      0.60        20
#
#     accuracy                           0.57        40
#    macro avg       0.58      0.57      0.57        40
# weighted avg       0.58      0.57      0.57        40
#
# SVM AUC value: 0.5375
#
# SVM accuracy for PCA: 0.75
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        20
#            1       0.73      0.80      0.76        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# SVM AUC value for PCA: 0.81
# KNN accuracy: 0.6
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.55      0.58        20
#            1       0.59      0.65      0.62        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# KNN AUC value: 0.56625
#
# KNN accuracy for PCA: 0.75
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76        20
#            1       0.78      0.70      0.74        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# KNN AUC value for PCA 0.81
# Random Forest accuracy: 0.5
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.50      0.40      0.44        20
#            1       0.50      0.60      0.55        20
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.49        40
# weighted avg       0.50      0.50      0.49        40
#
# Random Forest AUC value: 0.51
#
# Random Forest accuracy for PCA: 0.725
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72        20
#            1       0.71      0.75      0.73        20
#
#     accuracy                           0.72        40
#    macro avg       0.73      0.72      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# Random Forest AUC value for PCA: 0.795
# Logistic Regression accuracy: 0.525
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.45      0.49        20
#            1       0.52      0.60      0.56        20
#
#     accuracy                           0.53        40
#    macro avg       0.53      0.53      0.52        40
# weighted avg       0.53      0.53      0.52        40
#
# Logistic Regression AUC value: 0.46249999999999997
#
# Logistic Regression accuracy for PCA: 0.775
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.76      0.80      0.78        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# Logistic Regression AUC value for PCA 0.8125
# [0]	validation_0-logloss:0.71004
# [1]	validation_0-logloss:0.71712
# [2]	validation_0-logloss:0.68853
# [3]	validation_0-logloss:0.72288
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [4]	validation_0-logloss:0.72255
# XGB accuracy: 0.55
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.45      0.50        20
#            1       0.54      0.65      0.59        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# XGB AUC value: 0.60875
# [0]	validation_0-logloss:0.59434
# [1]	validation_0-logloss:0.58002
# [2]	validation_0-logloss:0.54584
# [3]	validation_0-logloss:0.56794
# [4]	validation_0-logloss:0.58576
#
# XGB accuracy for PCA: 0.725
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72        20
#            1       0.71      0.75      0.73        20
#
#     accuracy                           0.72        40
#    macro avg       0.73      0.72      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# XBG AUC for PCA: 0.81375
# [[14  6]
#  [ 5 15]]
# ['Anxiety+AEI_Delta_PSD', 0.475, 0.51, 0.475, 0.545, 0.525, 0.545, 0.45, 0.5025, 0.7, 0.64625] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.775, 0.87, 0.75, 0.8075000000000001, 0.775, 0.7875, 0.775, 0.8524999999999999, 0.775, 0.8275] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.675, 0.6000000000000001, 0.475, 0.53, 0.5, 0.48625, 0.7, 0.5974999999999999, 0.35, 0.41125] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.725, 0.8225, 0.675, 0.775, 0.675, 0.84125, 0.75, 0.83, 0.7, 0.85] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.475, 0.49249999999999994, 0.525, 0.5075000000000001, 0.4, 0.49874999999999997, 0.525, 0.53, 0.525, 0.5137499999999999] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.7, 0.81125, 0.725, 0.8049999999999999, 0.725, 0.7949999999999999, 0.675, 0.8049999999999999, 0.775, 0.8512499999999998] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSD', 0.45, 0.5549999999999999, 0.625, 0.5625, 0.5, 0.4975, 0.45, 0.48750000000000004, 0.475, 0.54125] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSDPCA', 0.775, 0.845, 0.8, 0.81625, 0.8, 0.8724999999999999, 0.775, 0.835, 0.775, 0.8612500000000001] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSD', 0.575, 0.5375, 0.6, 0.56625, 0.5, 0.51, 0.525, 0.46249999999999997, 0.55, 0.60875] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSDPCA', 0.75, 0.81, 0.75, 0.81, 0.725, 0.795, 0.775, 0.8125, 0.725, 0.81375] <class 'list'> 11
#
# Gamma columns:
#  ['age', 'education', 'IQ', 'AB.F.gamma.a.FP1', 'AB.F.gamma.b.FP2', 'AB.F.gamma.c.F7', 'AB.F.gamma.d.F3', 'AB.F.gamma.e.Fz', 'AB.F.gamma.f.F4', 'AB.F.gamma.g.F8', 'AB.F.gamma.h.T3', 'AB.F.gamma.i.C3', 'AB.F.gamma.j.Cz', 'AB.F.gamma.k.C4', 'AB.F.gamma.l.T4', 'AB.F.gamma.m.T5', 'AB.F.gamma.n.P3', 'AB.F.gamma.o.Pz', 'AB.F.gamma.p.P4', 'AB.F.gamma.q.T6', 'AB.F.gamma.r.O1', 'AB.F.gamma.s.O2', 'Class']
# SVM accuracy: 0.4
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.30      0.15      0.20        20
#            1       0.43      0.65      0.52        20
#
#     accuracy                           0.40        40
#    macro avg       0.37      0.40      0.36        40
# weighted avg       0.37      0.40      0.36        40
#
# SVM AUC value: 0.38000000000000006
#
# SVM accuracy for PCA: 0.75
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        20
#            1       0.73      0.80      0.76        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# SVM AUC value for PCA: 0.7675
# KNN accuracy: 0.6
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.65      0.62        20
#            1       0.61      0.55      0.58        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# KNN AUC value: 0.5625
#
# KNN accuracy for PCA: 0.75
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77        20
#            1       0.81      0.65      0.72        20
#
#     accuracy                           0.75        40
#    macro avg       0.76      0.75      0.75        40
# weighted avg       0.76      0.75      0.75        40
#
# KNN AUC value for PCA 0.79125
# Random Forest accuracy: 0.4
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.36      0.25      0.29        20
#            1       0.42      0.55      0.48        20
#
#     accuracy                           0.40        40
#    macro avg       0.39      0.40      0.39        40
# weighted avg       0.39      0.40      0.39        40
#
# Random Forest AUC value: 0.37875000000000003
#
# Random Forest accuracy for PCA: 0.775
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.76      0.80      0.78        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# Random Forest AUC value for PCA: 0.8012499999999999
# Logistic Regression accuracy: 0.375
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.14      0.05      0.07        20
#            1       0.42      0.70      0.53        20
#
#     accuracy                           0.38        40
#    macro avg       0.28      0.38      0.30        40
# weighted avg       0.28      0.38      0.30        40
#
# Logistic Regression AUC value: 0.38000000000000006
#
# Logistic Regression accuracy for PCA: 0.775
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.76      0.80      0.78        20
#
#     accuracy                           0.78        40
#    macro avg       0.78      0.78      0.77        40
# weighted avg       0.78      0.78      0.77        40
#
# Logistic Regression AUC value for PCA 0.7725
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0]	validation_0-logloss:0.77329
# [1]	validation_0-logloss:0.82425
# [2]	validation_0-logloss:0.84007
# XGB accuracy: 0.375
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.31      0.20      0.24        20
#            1       0.41      0.55      0.47        20
#
#     accuracy                           0.38        40
#    macro avg       0.36      0.38      0.36        40
# weighted avg       0.36      0.38      0.36        40
#
# XGB AUC value: 0.25
# [0]	validation_0-logloss:0.62740
# [1]	validation_0-logloss:0.59044
# [2]	validation_0-logloss:0.58327
# [3]	validation_0-logloss:0.57972
# [4]	validation_0-logloss:0.57141
# [5]	validation_0-logloss:0.57968
# [6]	validation_0-logloss:0.58881
#
# XGB accuracy for PCA: 0.65
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67        20
#            1       0.67      0.60      0.63        20
#
#     accuracy                           0.65        40
#    macro avg       0.65      0.65      0.65        40
# weighted avg       0.65      0.65      0.65        40
#
# XBG AUC for PCA: 0.75375
# [[14  6]
#  [ 8 12]]
# ['Anxiety+AEI_Delta_PSD', 0.475, 0.51, 0.475, 0.545, 0.525, 0.545, 0.45, 0.5025, 0.7, 0.64625] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.775, 0.87, 0.75, 0.8075000000000001, 0.775, 0.7875, 0.775, 0.8524999999999999, 0.775, 0.8275] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.675, 0.6000000000000001, 0.475, 0.53, 0.5, 0.48625, 0.7, 0.5974999999999999, 0.35, 0.41125] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.725, 0.8225, 0.675, 0.775, 0.675, 0.84125, 0.75, 0.83, 0.7, 0.85] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.475, 0.49249999999999994, 0.525, 0.5075000000000001, 0.4, 0.49874999999999997, 0.525, 0.53, 0.525, 0.5137499999999999] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.7, 0.81125, 0.725, 0.8049999999999999, 0.725, 0.7949999999999999, 0.675, 0.8049999999999999, 0.775, 0.8512499999999998] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSD', 0.45, 0.5549999999999999, 0.625, 0.5625, 0.5, 0.4975, 0.45, 0.48750000000000004, 0.475, 0.54125] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSDPCA', 0.775, 0.845, 0.8, 0.81625, 0.8, 0.8724999999999999, 0.775, 0.835, 0.775, 0.8612500000000001] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSD', 0.575, 0.5375, 0.6, 0.56625, 0.5, 0.51, 0.525, 0.46249999999999997, 0.55, 0.60875] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSDPCA', 0.75, 0.81, 0.75, 0.81, 0.725, 0.795, 0.775, 0.8125, 0.725, 0.81375] <class 'list'> 11
# ['Anxiety+AEI_Gamma_PSD', 0.4, 0.38000000000000006, 0.6, 0.5625, 0.4, 0.37875000000000003, 0.375, 0.38000000000000006, 0.375, 0.25] <class 'list'> 11
# ['Anxiety+AEI_Gamma_PSDPCA', 0.75, 0.7675, 0.75, 0.79125, 0.775, 0.8012499999999999, 0.775, 0.7725, 0.65, 0.75375] <class 'list'> 11
#
# All columns:
#  ['age', 'education', 'IQ', 'AB.A.delta.a.FP1', 'AB.A.delta.b.FP2', 'AB.A.delta.c.F7', 'AB.A.delta.d.F3', 'AB.A.delta.e.Fz', 'AB.A.delta.f.F4', 'AB.A.delta.g.F8', 'AB.A.delta.h.T3', 'AB.A.delta.i.C3', 'AB.A.delta.j.Cz', 'AB.A.delta.k.C4', 'AB.A.delta.l.T4', 'AB.A.delta.m.T5', 'AB.A.delta.n.P3', 'AB.A.delta.o.Pz', 'AB.A.delta.p.P4', 'AB.A.delta.q.T6', 'AB.A.delta.r.O1', 'AB.A.delta.s.O2', 'AB.B.theta.a.FP1', 'AB.B.theta.b.FP2', 'AB.B.theta.c.F7', 'AB.B.theta.d.F3', 'AB.B.theta.e.Fz', 'AB.B.theta.f.F4', 'AB.B.theta.g.F8', 'AB.B.theta.h.T3', 'AB.B.theta.i.C3', 'AB.B.theta.j.Cz', 'AB.B.theta.k.C4', 'AB.B.theta.l.T4', 'AB.B.theta.m.T5', 'AB.B.theta.n.P3', 'AB.B.theta.o.Pz', 'AB.B.theta.p.P4', 'AB.B.theta.q.T6', 'AB.B.theta.r.O1', 'AB.B.theta.s.O2', 'AB.C.alpha.a.FP1', 'AB.C.alpha.b.FP2', 'AB.C.alpha.c.F7', 'AB.C.alpha.d.F3', 'AB.C.alpha.e.Fz', 'AB.C.alpha.f.F4', 'AB.C.alpha.g.F8', 'AB.C.alpha.h.T3', 'AB.C.alpha.i.C3', 'AB.C.alpha.j.Cz', 'AB.C.alpha.k.C4', 'AB.C.alpha.l.T4', 'AB.C.alpha.m.T5', 'AB.C.alpha.n.P3', 'AB.C.alpha.o.Pz', 'AB.C.alpha.p.P4', 'AB.C.alpha.q.T6', 'AB.C.alpha.r.O1', 'AB.C.alpha.s.O2', 'AB.D.beta.a.FP1', 'AB.D.beta.b.FP2', 'AB.D.beta.c.F7', 'AB.D.beta.d.F3', 'AB.D.beta.e.Fz', 'AB.D.beta.f.F4', 'AB.D.beta.g.F8', 'AB.D.beta.h.T3', 'AB.D.beta.i.C3', 'AB.D.beta.j.Cz', 'AB.D.beta.k.C4', 'AB.D.beta.l.T4', 'AB.D.beta.m.T5', 'AB.D.beta.n.P3', 'AB.D.beta.o.Pz', 'AB.D.beta.p.P4', 'AB.D.beta.q.T6', 'AB.D.beta.r.O1', 'AB.D.beta.s.O2', 'AB.E.highbeta.a.FP1', 'AB.E.highbeta.b.FP2', 'AB.E.highbeta.c.F7', 'AB.E.highbeta.d.F3', 'AB.E.highbeta.e.Fz', 'AB.E.highbeta.f.F4', 'AB.E.highbeta.g.F8', 'AB.E.highbeta.h.T3', 'AB.E.highbeta.i.C3', 'AB.E.highbeta.j.Cz', 'AB.E.highbeta.k.C4', 'AB.E.highbeta.l.T4', 'AB.E.highbeta.m.T5', 'AB.E.highbeta.n.P3', 'AB.E.highbeta.o.Pz', 'AB.E.highbeta.p.P4', 'AB.E.highbeta.q.T6', 'AB.E.highbeta.r.O1', 'AB.E.highbeta.s.O2', 'AB.F.gamma.a.FP1', 'AB.F.gamma.b.FP2', 'AB.F.gamma.c.F7', 'AB.F.gamma.d.F3', 'AB.F.gamma.e.Fz', 'AB.F.gamma.f.F4', 'AB.F.gamma.g.F8', 'AB.F.gamma.h.T3', 'AB.F.gamma.i.C3', 'AB.F.gamma.j.Cz', 'AB.F.gamma.k.C4', 'AB.F.gamma.l.T4', 'AB.F.gamma.m.T5', 'AB.F.gamma.n.P3', 'AB.F.gamma.o.Pz', 'AB.F.gamma.p.P4', 'AB.F.gamma.q.T6', 'AB.F.gamma.r.O1', 'AB.F.gamma.s.O2', 'Class']
# SVM accuracy: 0.6
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.75      0.65        20
#            1       0.64      0.45      0.53        20
#
#     accuracy                           0.60        40
#    macro avg       0.61      0.60      0.59        40
# weighted avg       0.61      0.60      0.59        40
#
# SVM AUC value: 0.645
#
# SVM accuracy for PCA: 0.75
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        20
#            1       0.73      0.80      0.76        20
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.75      0.75        40
# weighted avg       0.75      0.75      0.75        40
#
# SVM AUC value for PCA: 0.9099999999999999
# KNN accuracy: 0.575
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.70      0.62        20
#            1       0.60      0.45      0.51        20
#
#     accuracy                           0.57        40
#    macro avg       0.58      0.57      0.57        40
# weighted avg       0.58      0.57      0.57        40
#
# KNN AUC value: 0.5525
#
# KNN accuracy for PCA: 0.7
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        20
#            1       0.75      0.60      0.67        20
#
#     accuracy                           0.70        40
#    macro avg       0.71      0.70      0.70        40
# weighted avg       0.71      0.70      0.70        40
#
# KNN AUC value for PCA 0.8275
# Random Forest accuracy: 0.6
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64        20
#            1       0.62      0.50      0.56        20
#
#     accuracy                           0.60        40
#    macro avg       0.60      0.60      0.60        40
# weighted avg       0.60      0.60      0.60        40
#
# Random Forest AUC value: 0.5525
#
# Random Forest accuracy for PCA: 0.725
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.80      0.60      0.69        20
#            1       0.68      0.85      0.76        20
#
#     accuracy                           0.72        40
#    macro avg       0.74      0.72      0.72        40
# weighted avg       0.74      0.72      0.72        40
#
# Random Forest AUC value for PCA: 0.81125
# Logistic Regression accuracy: 0.55
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.65      0.59        20
#            1       0.56      0.45      0.50        20
#
#     accuracy                           0.55        40
#    macro avg       0.55      0.55      0.55        40
# weighted avg       0.55      0.55      0.55        40
#
# Logistic Regression AUC value: 0.6499999999999999
#
# Logistic Regression accuracy for PCA: 0.725
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.76      0.65      0.70        20
#            1       0.70      0.80      0.74        20
#
#     accuracy                           0.72        40
#    macro avg       0.73      0.73      0.72        40
# weighted avg       0.73      0.72      0.72        40
#
# Logistic Regression AUC value for PCA 0.895
# [0]	validation_0-logloss:0.65140
# [1]	validation_0-logloss:0.67059
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# XGB accuracy: 0.65
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.55      0.61        20
#            1       0.62      0.75      0.68        20
#
#     accuracy                           0.65        40
#    macro avg       0.66      0.65      0.65        40
# weighted avg       0.66      0.65      0.65        40
#
# XGB AUC value: 0.68625
# [0]	validation_0-logloss:0.63480
# [1]	validation_0-logloss:0.59355
# [2]	validation_0-logloss:0.58244
# [3]	validation_0-logloss:0.55942
# [4]	validation_0-logloss:0.53861
# [5]	validation_0-logloss:0.52938
# [6]	validation_0-logloss:0.53838
# [7]	validation_0-logloss:0.52895
# [8]	validation_0-logloss:0.50069
# [9]	validation_0-logloss:0.49538
# [10]	validation_0-logloss:0.49322
# [11]	validation_0-logloss:0.48861
# [12]	validation_0-logloss:0.50097
# [13]	validation_0-logloss:0.50240
#
# XGB accuracy for PCA: 0.775
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.92      0.60      0.73        20
#            1       0.70      0.95      0.81        20
#
#     accuracy                           0.78        40
#    macro avg       0.81      0.77      0.77        40
# weighted avg       0.81      0.78      0.77        40
#
# XBG AUC for PCA: 0.8500000000000001
# [[12  8]
#  [ 1 19]]
# ['Anxiety+AEI_Delta_PSD', 0.475, 0.51, 0.475, 0.545, 0.525, 0.545, 0.45, 0.5025, 0.7, 0.64625] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.775, 0.87, 0.75, 0.8075000000000001, 0.775, 0.7875, 0.775, 0.8524999999999999, 0.775, 0.8275] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.675, 0.6000000000000001, 0.475, 0.53, 0.5, 0.48625, 0.7, 0.5974999999999999, 0.35, 0.41125] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.725, 0.8225, 0.675, 0.775, 0.675, 0.84125, 0.75, 0.83, 0.7, 0.85] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.475, 0.49249999999999994, 0.525, 0.5075000000000001, 0.4, 0.49874999999999997, 0.525, 0.53, 0.525, 0.5137499999999999] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.7, 0.81125, 0.725, 0.8049999999999999, 0.725, 0.7949999999999999, 0.675, 0.8049999999999999, 0.775, 0.8512499999999998] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSD', 0.45, 0.5549999999999999, 0.625, 0.5625, 0.5, 0.4975, 0.45, 0.48750000000000004, 0.475, 0.54125] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSDPCA', 0.775, 0.845, 0.8, 0.81625, 0.8, 0.8724999999999999, 0.775, 0.835, 0.775, 0.8612500000000001] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSD', 0.575, 0.5375, 0.6, 0.56625, 0.5, 0.51, 0.525, 0.46249999999999997, 0.55, 0.60875] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSDPCA', 0.75, 0.81, 0.75, 0.81, 0.725, 0.795, 0.775, 0.8125, 0.725, 0.81375] <class 'list'> 11
# ['Anxiety+AEI_Gamma_PSD', 0.4, 0.38000000000000006, 0.6, 0.5625, 0.4, 0.37875000000000003, 0.375, 0.38000000000000006, 0.375, 0.25] <class 'list'> 11
# ['Anxiety+AEI_Gamma_PSDPCA', 0.75, 0.7675, 0.75, 0.79125, 0.775, 0.8012499999999999, 0.775, 0.7725, 0.65, 0.75375] <class 'list'> 11
# ['Anxiety+AEI_All_PSD', 0.6, 0.645, 0.575, 0.5525, 0.6, 0.5525, 0.55, 0.6499999999999999, 0.65, 0.68625] <class 'list'> 11
# ['Anxiety+AEI_All_PSDPCA', 0.75, 0.9099999999999999, 0.7, 0.8275, 0.725, 0.81125, 0.725, 0.895, 0.775, 0.8500000000000001] <class 'list'> 11
