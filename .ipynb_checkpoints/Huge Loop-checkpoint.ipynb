# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.datasets import make_blobs
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
# Load in your data here
data = pd.read_csv("AEIanxietyhc_allPSD.csv") #file name here
print(data.shape[1])
print(data.shape[1])
print(data.iloc[:,117])
# Out:
# 118
# 118
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 194    0
# 195    0
# 196    0
# 197    0
# 198    0
# Name: Class, Length: 199, dtype: int64

# %%
bands = [
    ('Delta', data.iloc[:, list(range(0,22))+[-1]]),
    ('Theta', data.iloc[:, list(range(0,3)) + list(range(22,41))+[-1]]),
    ('Alpha', data.iloc[:, list(range(0,3)) + list(range(41,60))+[-1]]),
    ('Beta', data.iloc[:, list(range(0,3)) + list(range(60,79))+[-1]]),
    ('HighBeta', data.iloc[:, list(range(0,3)) + list(range(79,98))+[-1]]),
    ('Gamma', data.iloc[:, list(range(0,3)) + list(range(98,117))+[-1]]),
    ('All', data.iloc[:, 0:118])
]
all_model_data = []

#bands = [delta, theta, alpha, beta, highbeta, gamma, allb]

for label, band in bands:
    # Data preprocessing
    print(f"\n{label} columns:\n", band.columns.tolist())
    X = band.drop('Class', axis=1)
    y = band['Class']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, stratify=None)
    pca = PCA(0.95)
    X_pca = pca.fit_transform(X)
    X_pca.shape
    X = X.dropna()
    X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.1, random_state=30)
    svclassifier = SVC(kernel='linear',probability=True)
    svclassifier.fit(X_train, y_train)
    y_pred = svclassifier.predict(X_test)
    print('SVM accuracy:', svclassifier.score(X_test, y_test))
    print('SVM classification report:\n', classification_report(y_test, y_pred))
    y_scores = svclassifier.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    # Calculate AUC
    svm_auc = auc(fpr, tpr)
    print('SVM AUC value:', svm_auc)
    newsvm=SVC(kernel='linear', probability=True)
    newsvm.fit(X_train_pca, y_train)
    y_pred = newsvm.predict(X_test_pca)
    print('\nSVM accuracy for PCA:', newsvm.score(X_test_pca, y_test))
    print('SVM classification report for PCA:\n', classification_report(y_test, y_pred))
    y_scores = newsvm.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pcasvm_auc = auc(fpr, tpr)
    print('SVM AUC value for PCA:', pcasvm_auc)
    
    knn = KNeighborsClassifier(n_neighbors=10)
    knn.fit(X_train, y_train)
    print('KNN accuracy:', knn.score(X_test, y_test))
    y_pred = knn.predict(X_test)
    print('KNN classification report:\n',classification_report(y_test, y_pred))
    y_scores = knn.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    knn_auc = auc(fpr, tpr)
    print('KNN AUC value:', knn_auc)
    pknn = KNeighborsClassifier(n_neighbors=10)
    pknn.fit(X_train_pca, y_train)
    print('\nKNN accuracy for PCA:', pknn.score(X_test_pca, y_test))
    y_pred = pknn.predict(X_test_pca)
    print('KNN classification report for PCA\n', classification_report(y_test, y_pred))
    y_scores = pknn.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pcaknn_auc = auc(fpr, tpr)
    print('KNN AUC value for PCA',pcaknn_auc)
    
    model = RandomForestClassifier(n_estimators=40)
    model.fit(X_train, y_train)
    print('Random Forest accuracy:', model.score(X_test, y_test))
    y_pred = model.predict(X_test)
    print('Random Forest classification report\n',classification_report(y_test, y_pred))
    y_scores = model.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    rf_auc = auc(fpr, tpr)
    print('Random Forest AUC value:', rf_auc)
    pmodel = RandomForestClassifier(n_estimators=40)
    pmodel.fit(X_train_pca, y_train)
    print('\nRandom Forest accuracy for PCA:', pmodel.score(X_test_pca, y_test))
    y_pred = pmodel.predict(X_test_pca)
    print('Random Forest classification report for PCA:\n',classification_report(y_test, y_pred))
    y_scores = pmodel.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pcarf_auc = auc(fpr, tpr)
    print('Random Forest AUC value for PCA:', pcarf_auc)
    
    lg = LogisticRegression()
    lg.fit(X_train, y_train)
    print('Logistic Regression accuracy:', lg.score(X_test, y_test))
    y_pred = lg.predict(X_test)
    print('Logistic Regression classification report:\n',classification_report(y_test, y_pred))
    y_scores = lg.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    lg_auc = auc(fpr, tpr)
    print('Logistic Regression AUC value:',lg_auc)
    plg = LogisticRegression()
    plg.fit(X_train_pca, y_train)
    print('\nLogistic Regression accuracy for PCA:',plg.score(X_test_pca, y_test))
    y_pred = plg.predict(X_test_pca)
    print('Logistic Regression classification report for PCA:\n',classification_report(y_test, y_pred))
    y_scores = plg.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pcalg_auc = auc(fpr, tpr)
    print('Logistic Regression AUC value for PCA',pcalg_auc)
    
    clf = xgb.XGBClassifier(tree_method="hist", early_stopping_rounds=2)
    clf.fit(X_train, y_train, eval_set=[(X_test, y_test)])
    y_pred = clf.predict(X_test)
    print('XGB accuracy:',clf.score(X_test, y_test))
    print('XGB Classification report:\n',classification_report(y_test, y_pred))
    y_scores = clf.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    xgb_auc = auc(fpr, tpr)
    print('XGB AUC value:',xgb_auc)
    pxgb = xgb.XGBClassifier(tree_method="hist", early_stopping_rounds=2)
    pxgb.fit(X_train_pca, y_train, eval_set=[(X_test_pca, y_test)])
    print('\nXGB accuracy for PCA:', pxgb.score(X_test_pca, y_test))
    y_pred = pxgb.predict(X_test_pca)
    print('XGB classification report for PCA:\n',classification_report(y_test, y_pred))
    y_scores = pxgb.predict_proba(X_test_pca)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    pxgb_auc = auc(fpr, tpr)
    print('XBG AUC for PCA:', pxgb_auc)
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    model_row = [
        f"Anxiety+AEI_{label}_PSD",
        svclassifier.score(X_test, y_test), svm_auc,
        knn.score(X_test, y_test), knn_auc,
        model.score(X_test, y_test), rf_auc,
        lg.score(X_test, y_test), lg_auc,
        clf.score(X_test, y_test), xgb_auc
    ]
    pca_row = [
        f"Anxiety+AEI_{label}_PSDPCA", 
        newsvm.score(X_test_pca, y_test), pcasvm_auc,
        pknn.score(X_test_pca, y_test),pcaknn_auc,
        pmodel.score(X_test_pca, y_test),pcarf_auc,
        plg.score(X_test_pca, y_test),pcalg_auc,
        pxgb.score(X_test_pca, y_test), pxgb_auc
    ]
    all_model_data.append(model_row)
    all_model_data.append(pca_row)
    for row in all_model_data:
        print(row, type(row), len(row) if hasattr(row, '__len__') else 'Not iterable')
columns = ['Combination', 'SVM Accuracy', 'SVM AUC', 
           'KNN Accuracy', 'KNN AUC', 
           'Random Forest Accuracy','Random Forest AUC', 
           'Logistic Regression Accuracy', 'Logistic Regression AUC', 
           'XGB Accuracy', 'XGB AUC']
    
df = pd.DataFrame(all_model_data, columns=columns)
df.to_csv('masterdata.csv', index=False)
# Out:
# Delta columns:
#  ['age', 'education', 'IQ', 'AB.A.delta.a.FP1', 'AB.A.delta.b.FP2', 'AB.A.delta.c.F7', 'AB.A.delta.d.F3', 'AB.A.delta.e.Fz', 'AB.A.delta.f.F4', 'AB.A.delta.g.F8', 'AB.A.delta.h.T3', 'AB.A.delta.i.C3', 'AB.A.delta.j.Cz', 'AB.A.delta.k.C4', 'AB.A.delta.l.T4', 'AB.A.delta.m.T5', 'AB.A.delta.n.P3', 'AB.A.delta.o.Pz', 'AB.A.delta.p.P4', 'AB.A.delta.q.T6', 'AB.A.delta.r.O1', 'AB.A.delta.s.O2', 'Class']
# SVM accuracy: 0.6
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.45      0.56        11
#            1       0.54      0.78      0.64         9
#
#     accuracy                           0.60        20
#    macro avg       0.63      0.62      0.60        20
# weighted avg       0.64      0.60      0.59        20
#
# SVM AUC value: 0.6363636363636364
#
# SVM accuracy for PCA: 0.75
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        11
#            1       0.67      0.89      0.76         9
#
#     accuracy                           0.75        20
#    macro avg       0.77      0.76      0.75        20
# weighted avg       0.78      0.75      0.75        20
#
# SVM AUC value for PCA: 0.9494949494949494
# KNN accuracy: 0.6
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.55      0.60        11
#            1       0.55      0.67      0.60         9
#
#     accuracy                           0.60        20
#    macro avg       0.61      0.61      0.60        20
# weighted avg       0.61      0.60      0.60        20
#
# KNN AUC value: 0.6515151515151516
#
# KNN accuracy for PCA: 0.7
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73        11
#            1       0.67      0.67      0.67         9
#
#     accuracy                           0.70        20
#    macro avg       0.70      0.70      0.70        20
# weighted avg       0.70      0.70      0.70        20
#
# KNN AUC value for PCA 0.8333333333333334
# Random Forest accuracy: 0.3
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.20      0.09      0.12        11
#            1       0.33      0.56      0.42         9
#
#     accuracy                           0.30        20
#    macro avg       0.27      0.32      0.27        20
# weighted avg       0.26      0.30      0.26        20
#
# Random Forest AUC value: 0.38888888888888895
#
# Random Forest accuracy for PCA: 0.6
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.80      0.36      0.50        11
#            1       0.53      0.89      0.67         9
#
#     accuracy                           0.60        20
#    macro avg       0.67      0.63      0.58        20
# weighted avg       0.68      0.60      0.57        20
#
# Random Forest AUC value for PCA: 0.8888888888888888
# Logistic Regression accuracy: 0.55
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.36      0.47        11
#            1       0.50      0.78      0.61         9
#
#     accuracy                           0.55        20
#    macro avg       0.58      0.57      0.54        20
# weighted avg       0.59      0.55      0.53        20
#
# Logistic Regression AUC value: 0.6363636363636364
#
# Logistic Regression accuracy for PCA: 0.8
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.73      0.89      0.80         9
#
#     accuracy                           0.80        20
#    macro avg       0.81      0.81      0.80        20
# weighted avg       0.82      0.80      0.80        20
#
# Logistic Regression AUC value for PCA 0.9191919191919191
# [0]	validation_0-logloss:0.71485
# [1]	validation_0-logloss:0.72322
# [2]	validation_0-logloss:0.74276
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# XGB accuracy: 0.6
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.36      0.50        11
#            1       0.53      0.89      0.67         9
#
#     accuracy                           0.60        20
#    macro avg       0.67      0.63      0.58        20
# weighted avg       0.68      0.60      0.57        20
#
# XGB AUC value: 0.5151515151515151
# [0]	validation_0-logloss:0.60617
# [1]	validation_0-logloss:0.55701
# [2]	validation_0-logloss:0.55426
# [3]	validation_0-logloss:0.55327
# [4]	validation_0-logloss:0.56953
# [5]	validation_0-logloss:0.59322
#
# XGB accuracy for PCA: 0.8
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78        11
#            1       0.69      1.00      0.82         9
#
#     accuracy                           0.80        20
#    macro avg       0.85      0.82      0.80        20
# weighted avg       0.86      0.80      0.80        20
#
# XBG AUC for PCA: 0.9191919191919191
# [[7 4]
#  [0 9]]
# ['Anxiety+AEI_Delta_PSD', 0.6, 0.6363636363636364, 0.6, 0.6515151515151516, 0.3, 0.38888888888888895, 0.55, 0.6363636363636364, 0.6, 0.5151515151515151] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.75, 0.9494949494949494, 0.7, 0.8333333333333334, 0.6, 0.8888888888888888, 0.8, 0.9191919191919191, 0.8, 0.9191919191919191] <class 'list'> 11
#
# Theta columns:
#  ['age', 'education', 'IQ', 'AB.B.theta.a.FP1', 'AB.B.theta.b.FP2', 'AB.B.theta.c.F7', 'AB.B.theta.d.F3', 'AB.B.theta.e.Fz', 'AB.B.theta.f.F4', 'AB.B.theta.g.F8', 'AB.B.theta.h.T3', 'AB.B.theta.i.C3', 'AB.B.theta.j.Cz', 'AB.B.theta.k.C4', 'AB.B.theta.l.T4', 'AB.B.theta.m.T5', 'AB.B.theta.n.P3', 'AB.B.theta.o.Pz', 'AB.B.theta.p.P4', 'AB.B.theta.q.T6', 'AB.B.theta.r.O1', 'AB.B.theta.s.O2', 'Class']
# SVM accuracy: 0.35
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        11
#            1       0.39      0.78      0.52         9
#
#     accuracy                           0.35        20
#    macro avg       0.19      0.39      0.26        20
# weighted avg       0.17      0.35      0.23        20
#
# SVM AUC value: 0.48484848484848486
#
# SVM accuracy for PCA: 0.75
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71        11
#            1       0.64      1.00      0.78         9
#
#     accuracy                           0.75        20
#    macro avg       0.82      0.77      0.74        20
# weighted avg       0.84      0.75      0.74        20
#
# SVM AUC value for PCA: 0.9191919191919191
# KNN accuracy: 0.45
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.45      0.48        11
#            1       0.40      0.44      0.42         9
#
#     accuracy                           0.45        20
#    macro avg       0.45      0.45      0.45        20
# weighted avg       0.45      0.45      0.45        20
#
# KNN AUC value: 0.4747474747474747
#
# KNN accuracy for PCA: 0.75
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76        11
#            1       0.70      0.78      0.74         9
#
#     accuracy                           0.75        20
#    macro avg       0.75      0.75      0.75        20
# weighted avg       0.76      0.75      0.75        20
#
# KNN AUC value for PCA 0.8939393939393939
# Random Forest accuracy: 0.4
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.44      0.36      0.40        11
#            1       0.36      0.44      0.40         9
#
#     accuracy                           0.40        20
#    macro avg       0.40      0.40      0.40        20
# weighted avg       0.41      0.40      0.40        20
#
# Random Forest AUC value: 0.48484848484848486
#
# Random Forest accuracy for PCA: 0.75
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        11
#            1       0.67      0.89      0.76         9
#
#     accuracy                           0.75        20
#    macro avg       0.77      0.76      0.75        20
# weighted avg       0.78      0.75      0.75        20
#
# Random Forest AUC value for PCA: 0.9191919191919191
# Logistic Regression accuracy: 0.5
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.27      0.38        11
#            1       0.47      0.78      0.58         9
#
#     accuracy                           0.50        20
#    macro avg       0.53      0.53      0.48        20
# weighted avg       0.54      0.50      0.47        20
#
# Logistic Regression AUC value: 0.6666666666666667
#
# Logistic Regression accuracy for PCA: 0.75
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71        11
#            1       0.64      1.00      0.78         9
#
#     accuracy                           0.75        20
#    macro avg       0.82      0.77      0.74        20
# weighted avg       0.84      0.75      0.74        20
#
# Logistic Regression AUC value for PCA 0.9191919191919191
# [0]	validation_0-logloss:0.73398
# [1]	validation_0-logloss:0.70981
# [2]	validation_0-logloss:0.73012
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# XGB accuracy: 0.55
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.27      0.40        11
#            1       0.50      0.89      0.64         9
#
#     accuracy                           0.55        20
#    macro avg       0.62      0.58      0.52        20
# weighted avg       0.64      0.55      0.51        20
#
# XGB AUC value: 0.6313131313131313
# [0]	validation_0-logloss:0.61676
# [1]	validation_0-logloss:0.57207
# [2]	validation_0-logloss:0.53379
# [3]	validation_0-logloss:0.53455
# [4]	validation_0-logloss:0.51789
# [5]	validation_0-logloss:0.54705
#
# XGB accuracy for PCA: 0.7
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.86      0.55      0.67        11
#            1       0.62      0.89      0.73         9
#
#     accuracy                           0.70        20
#    macro avg       0.74      0.72      0.70        20
# weighted avg       0.75      0.70      0.69        20
#
# XBG AUC for PCA: 0.8989898989898989
# [[6 5]
#  [1 8]]
# ['Anxiety+AEI_Delta_PSD', 0.6, 0.6363636363636364, 0.6, 0.6515151515151516, 0.3, 0.38888888888888895, 0.55, 0.6363636363636364, 0.6, 0.5151515151515151] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.75, 0.9494949494949494, 0.7, 0.8333333333333334, 0.6, 0.8888888888888888, 0.8, 0.9191919191919191, 0.8, 0.9191919191919191] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.35, 0.48484848484848486, 0.45, 0.4747474747474747, 0.4, 0.48484848484848486, 0.5, 0.6666666666666667, 0.55, 0.6313131313131313] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.75, 0.9191919191919191, 0.75, 0.8939393939393939, 0.75, 0.9191919191919191, 0.75, 0.9191919191919191, 0.7, 0.8989898989898989] <class 'list'> 11
#
# Alpha columns:
#  ['age', 'education', 'IQ', 'AB.C.alpha.a.FP1', 'AB.C.alpha.b.FP2', 'AB.C.alpha.c.F7', 'AB.C.alpha.d.F3', 'AB.C.alpha.e.Fz', 'AB.C.alpha.f.F4', 'AB.C.alpha.g.F8', 'AB.C.alpha.h.T3', 'AB.C.alpha.i.C3', 'AB.C.alpha.j.Cz', 'AB.C.alpha.k.C4', 'AB.C.alpha.l.T4', 'AB.C.alpha.m.T5', 'AB.C.alpha.n.P3', 'AB.C.alpha.o.Pz', 'AB.C.alpha.p.P4', 'AB.C.alpha.q.T6', 'AB.C.alpha.r.O1', 'AB.C.alpha.s.O2', 'Class']
# SVM accuracy: 0.65
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.45      0.59        11
#            1       0.57      0.89      0.70         9
#
#     accuracy                           0.65        20
#    macro avg       0.70      0.67      0.64        20
# weighted avg       0.72      0.65      0.64        20
#
# SVM AUC value: 0.303030303030303
#
# SVM accuracy for PCA: 0.75
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        11
#            1       0.67      0.89      0.76         9
#
#     accuracy                           0.75        20
#    macro avg       0.77      0.76      0.75        20
# weighted avg       0.78      0.75      0.75        20
#
# SVM AUC value for PCA: 0.9191919191919191
# KNN accuracy: 0.3
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.36      0.36      0.36        11
#            1       0.22      0.22      0.22         9
#
#     accuracy                           0.30        20
#    macro avg       0.29      0.29      0.29        20
# weighted avg       0.30      0.30      0.30        20
#
# KNN AUC value: 0.29292929292929293
#
# KNN accuracy for PCA: 0.8
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.73      0.89      0.80         9
#
#     accuracy                           0.80        20
#    macro avg       0.81      0.81      0.80        20
# weighted avg       0.82      0.80      0.80        20
#
# KNN AUC value for PCA 0.9141414141414141
# Random Forest accuracy: 0.45
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.50      0.45      0.48        11
#            1       0.40      0.44      0.42         9
#
#     accuracy                           0.45        20
#    macro avg       0.45      0.45      0.45        20
# weighted avg       0.45      0.45      0.45        20
#
# Random Forest AUC value: 0.601010101010101
#
# Random Forest accuracy for PCA: 0.75
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        11
#            1       0.67      0.89      0.76         9
#
#     accuracy                           0.75        20
#    macro avg       0.77      0.76      0.75        20
# weighted avg       0.78      0.75      0.75        20
#
# Random Forest AUC value for PCA: 0.9090909090909091
# Logistic Regression accuracy: 0.65
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.45      0.59        11
#            1       0.57      0.89      0.70         9
#
#     accuracy                           0.65        20
#    macro avg       0.70      0.67      0.64        20
# weighted avg       0.72      0.65      0.64        20
#
# Logistic Regression AUC value: 0.7272727272727272
#
# Logistic Regression accuracy for PCA: 0.7
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.86      0.55      0.67        11
#            1       0.62      0.89      0.73         9
#
#     accuracy                           0.70        20
#    macro avg       0.74      0.72      0.70        20
# weighted avg       0.75      0.70      0.69        20
#
# Logistic Regression AUC value for PCA 0.9191919191919191
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0]	validation_0-logloss:0.72179
# [1]	validation_0-logloss:0.73059
# XGB accuracy: 0.5
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.27      0.38        11
#            1       0.47      0.78      0.58         9
#
#     accuracy                           0.50        20
#    macro avg       0.53      0.53      0.48        20
# weighted avg       0.54      0.50      0.47        20
#
# XGB AUC value: 0.44949494949494956
# [0]	validation_0-logloss:0.59961
# [1]	validation_0-logloss:0.53893
# [2]	validation_0-logloss:0.49778
# [3]	validation_0-logloss:0.46973
# [4]	validation_0-logloss:0.45882
# [5]	validation_0-logloss:0.45818
# [6]	validation_0-logloss:0.45402
# [7]	validation_0-logloss:0.47257
#
# XGB accuracy for PCA: 0.8
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.73      0.89      0.80         9
#
#     accuracy                           0.80        20
#    macro avg       0.81      0.81      0.80        20
# weighted avg       0.82      0.80      0.80        20
#
# XBG AUC for PCA: 0.898989898989899
# [[8 3]
#  [1 8]]
# ['Anxiety+AEI_Delta_PSD', 0.6, 0.6363636363636364, 0.6, 0.6515151515151516, 0.3, 0.38888888888888895, 0.55, 0.6363636363636364, 0.6, 0.5151515151515151] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.75, 0.9494949494949494, 0.7, 0.8333333333333334, 0.6, 0.8888888888888888, 0.8, 0.9191919191919191, 0.8, 0.9191919191919191] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.35, 0.48484848484848486, 0.45, 0.4747474747474747, 0.4, 0.48484848484848486, 0.5, 0.6666666666666667, 0.55, 0.6313131313131313] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.75, 0.9191919191919191, 0.75, 0.8939393939393939, 0.75, 0.9191919191919191, 0.75, 0.9191919191919191, 0.7, 0.8989898989898989] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.65, 0.303030303030303, 0.3, 0.29292929292929293, 0.45, 0.601010101010101, 0.65, 0.7272727272727272, 0.5, 0.44949494949494956] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.75, 0.9191919191919191, 0.8, 0.9141414141414141, 0.75, 0.9090909090909091, 0.7, 0.9191919191919191, 0.8, 0.898989898989899] <class 'list'> 11
#
# Beta columns:
#  ['age', 'education', 'IQ', 'AB.D.beta.a.FP1', 'AB.D.beta.b.FP2', 'AB.D.beta.c.F7', 'AB.D.beta.d.F3', 'AB.D.beta.e.Fz', 'AB.D.beta.f.F4', 'AB.D.beta.g.F8', 'AB.D.beta.h.T3', 'AB.D.beta.i.C3', 'AB.D.beta.j.Cz', 'AB.D.beta.k.C4', 'AB.D.beta.l.T4', 'AB.D.beta.m.T5', 'AB.D.beta.n.P3', 'AB.D.beta.o.Pz', 'AB.D.beta.p.P4', 'AB.D.beta.q.T6', 'AB.D.beta.r.O1', 'AB.D.beta.s.O2', 'Class']
# SVM accuracy: 0.45
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52        11
#            1       0.38      0.33      0.35         9
#
#     accuracy                           0.45        20
#    macro avg       0.44      0.44      0.44        20
# weighted avg       0.44      0.45      0.45        20
#
# SVM AUC value: 0.42424242424242425
#
# SVM accuracy for PCA: 0.75
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71        11
#            1       0.64      1.00      0.78         9
#
#     accuracy                           0.75        20
#    macro avg       0.82      0.77      0.74        20
# weighted avg       0.84      0.75      0.74        20
#
# SVM AUC value for PCA: 0.9292929292929293
# KNN accuracy: 0.55
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61        11
#            1       0.50      0.44      0.47         9
#
#     accuracy                           0.55        20
#    macro avg       0.54      0.54      0.54        20
# weighted avg       0.55      0.55      0.55        20
#
# KNN AUC value: 0.5151515151515151
#
# KNN accuracy for PCA: 0.75
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76        11
#            1       0.70      0.78      0.74         9
#
#     accuracy                           0.75        20
#    macro avg       0.75      0.75      0.75        20
# weighted avg       0.76      0.75      0.75        20
#
# KNN AUC value for PCA 0.8737373737373737
# Random Forest accuracy: 0.55
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.60      0.55      0.57        11
#            1       0.50      0.56      0.53         9
#
#     accuracy                           0.55        20
#    macro avg       0.55      0.55      0.55        20
# weighted avg       0.55      0.55      0.55        20
#
# Random Forest AUC value: 0.5202020202020201
#
# Random Forest accuracy for PCA: 0.8
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.73      0.89      0.80         9
#
#     accuracy                           0.80        20
#    macro avg       0.81      0.81      0.80        20
# weighted avg       0.82      0.80      0.80        20
#
# Random Forest AUC value for PCA: 0.904040404040404
# Logistic Regression accuracy: 0.6
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.55      0.60        11
#            1       0.55      0.67      0.60         9
#
#     accuracy                           0.60        20
#    macro avg       0.61      0.61      0.60        20
# weighted avg       0.61      0.60      0.60        20
#
# Logistic Regression AUC value: 0.5151515151515151
#
# Logistic Regression accuracy for PCA: 0.8
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78        11
#            1       0.69      1.00      0.82         9
#
#     accuracy                           0.80        20
#    macro avg       0.85      0.82      0.80        20
# weighted avg       0.86      0.80      0.80        20
#
# Logistic Regression AUC value for PCA 0.9393939393939393
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0]	validation_0-logloss:0.69513
# [1]	validation_0-logloss:0.69975
# XGB accuracy: 0.45
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.36      0.42        11
#            1       0.42      0.56      0.48         9
#
#     accuracy                           0.45        20
#    macro avg       0.46      0.46      0.45        20
# weighted avg       0.46      0.45      0.45        20
#
# XGB AUC value: 0.5909090909090909
# [0]	validation_0-logloss:0.62328
# [1]	validation_0-logloss:0.56488
# [2]	validation_0-logloss:0.54096
# [3]	validation_0-logloss:0.48450
# [4]	validation_0-logloss:0.49018
#
# XGB accuracy for PCA: 0.8
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.73      0.89      0.80         9
#
#     accuracy                           0.80        20
#    macro avg       0.81      0.81      0.80        20
# weighted avg       0.82      0.80      0.80        20
#
# XBG AUC for PCA: 0.898989898989899
# [[8 3]
#  [1 8]]
# ['Anxiety+AEI_Delta_PSD', 0.6, 0.6363636363636364, 0.6, 0.6515151515151516, 0.3, 0.38888888888888895, 0.55, 0.6363636363636364, 0.6, 0.5151515151515151] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.75, 0.9494949494949494, 0.7, 0.8333333333333334, 0.6, 0.8888888888888888, 0.8, 0.9191919191919191, 0.8, 0.9191919191919191] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.35, 0.48484848484848486, 0.45, 0.4747474747474747, 0.4, 0.48484848484848486, 0.5, 0.6666666666666667, 0.55, 0.6313131313131313] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.75, 0.9191919191919191, 0.75, 0.8939393939393939, 0.75, 0.9191919191919191, 0.75, 0.9191919191919191, 0.7, 0.8989898989898989] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.65, 0.303030303030303, 0.3, 0.29292929292929293, 0.45, 0.601010101010101, 0.65, 0.7272727272727272, 0.5, 0.44949494949494956] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.75, 0.9191919191919191, 0.8, 0.9141414141414141, 0.75, 0.9090909090909091, 0.7, 0.9191919191919191, 0.8, 0.898989898989899] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSD', 0.45, 0.42424242424242425, 0.55, 0.5151515151515151, 0.55, 0.5202020202020201, 0.6, 0.5151515151515151, 0.45, 0.5909090909090909] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSDPCA', 0.75, 0.9292929292929293, 0.75, 0.8737373737373737, 0.8, 0.904040404040404, 0.8, 0.9393939393939393, 0.8, 0.898989898989899] <class 'list'> 11
#
# HighBeta columns:
#  ['age', 'education', 'IQ', 'AB.E.highbeta.a.FP1', 'AB.E.highbeta.b.FP2', 'AB.E.highbeta.c.F7', 'AB.E.highbeta.d.F3', 'AB.E.highbeta.e.Fz', 'AB.E.highbeta.f.F4', 'AB.E.highbeta.g.F8', 'AB.E.highbeta.h.T3', 'AB.E.highbeta.i.C3', 'AB.E.highbeta.j.Cz', 'AB.E.highbeta.k.C4', 'AB.E.highbeta.l.T4', 'AB.E.highbeta.m.T5', 'AB.E.highbeta.n.P3', 'AB.E.highbeta.o.Pz', 'AB.E.highbeta.p.P4', 'AB.E.highbeta.q.T6', 'AB.E.highbeta.r.O1', 'AB.E.highbeta.s.O2', 'Class']
# SVM accuracy: 0.55
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.27      0.40        11
#            1       0.50      0.89      0.64         9
#
#     accuracy                           0.55        20
#    macro avg       0.62      0.58      0.52        20
# weighted avg       0.64      0.55      0.51        20
#
# SVM AUC value: 0.6868686868686869
#
# SVM accuracy for PCA: 0.8
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78        11
#            1       0.69      1.00      0.82         9
#
#     accuracy                           0.80        20
#    macro avg       0.85      0.82      0.80        20
# weighted avg       0.86      0.80      0.80        20
#
# SVM AUC value for PCA: 0.9494949494949495
# KNN accuracy: 0.3
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.29      0.18      0.22        11
#            1       0.31      0.44      0.36         9
#
#     accuracy                           0.30        20
#    macro avg       0.30      0.31      0.29        20
# weighted avg       0.30      0.30      0.29        20
#
# KNN AUC value: 0.2777777777777778
#
# KNN accuracy for PCA: 0.8
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.73      0.89      0.80         9
#
#     accuracy                           0.80        20
#    macro avg       0.81      0.81      0.80        20
# weighted avg       0.82      0.80      0.80        20
#
# KNN AUC value for PCA 0.9343434343434343
# Random Forest accuracy: 0.6
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64        11
#            1       0.56      0.56      0.56         9
#
#     accuracy                           0.60        20
#    macro avg       0.60      0.60      0.60        20
# weighted avg       0.60      0.60      0.60        20
#
# Random Forest AUC value: 0.4393939393939394
#
# Random Forest accuracy for PCA: 0.75
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        11
#            1       0.67      0.89      0.76         9
#
#     accuracy                           0.75        20
#    macro avg       0.77      0.76      0.75        20
# weighted avg       0.78      0.75      0.75        20
#
# Random Forest AUC value for PCA: 0.8737373737373737
# Logistic Regression accuracy: 0.55
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.45      0.53        11
#            1       0.50      0.67      0.57         9
#
#     accuracy                           0.55        20
#    macro avg       0.56      0.56      0.55        20
# weighted avg       0.57      0.55      0.55        20
#
# Logistic Regression AUC value: 0.696969696969697
#
# Logistic Regression accuracy for PCA: 0.75
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71        11
#            1       0.64      1.00      0.78         9
#
#     accuracy                           0.75        20
#    macro avg       0.82      0.77      0.74        20
# weighted avg       0.84      0.75      0.74        20
#
# Logistic Regression AUC value for PCA 0.9494949494949495
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0]	validation_0-logloss:0.75763
# [1]	validation_0-logloss:0.75437
# [2]	validation_0-logloss:0.76147
# XGB accuracy: 0.45
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.18      0.27        11
#            1       0.44      0.78      0.56         9
#
#     accuracy                           0.45        20
#    macro avg       0.47      0.48      0.41        20
# weighted avg       0.47      0.45      0.40        20
#
# XGB AUC value: 0.45959595959595956
# [0]	validation_0-logloss:0.58473
# [1]	validation_0-logloss:0.56130
# [2]	validation_0-logloss:0.52714
# [3]	validation_0-logloss:0.50700
# [4]	validation_0-logloss:0.46949
# [5]	validation_0-logloss:0.47690
#
# XGB accuracy for PCA: 0.7
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.86      0.55      0.67        11
#            1       0.62      0.89      0.73         9
#
#     accuracy                           0.70        20
#    macro avg       0.74      0.72      0.70        20
# weighted avg       0.75      0.70      0.69        20
#
# XBG AUC for PCA: 0.9393939393939393
# [[6 5]
#  [1 8]]
# ['Anxiety+AEI_Delta_PSD', 0.6, 0.6363636363636364, 0.6, 0.6515151515151516, 0.3, 0.38888888888888895, 0.55, 0.6363636363636364, 0.6, 0.5151515151515151] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.75, 0.9494949494949494, 0.7, 0.8333333333333334, 0.6, 0.8888888888888888, 0.8, 0.9191919191919191, 0.8, 0.9191919191919191] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.35, 0.48484848484848486, 0.45, 0.4747474747474747, 0.4, 0.48484848484848486, 0.5, 0.6666666666666667, 0.55, 0.6313131313131313] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.75, 0.9191919191919191, 0.75, 0.8939393939393939, 0.75, 0.9191919191919191, 0.75, 0.9191919191919191, 0.7, 0.8989898989898989] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.65, 0.303030303030303, 0.3, 0.29292929292929293, 0.45, 0.601010101010101, 0.65, 0.7272727272727272, 0.5, 0.44949494949494956] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.75, 0.9191919191919191, 0.8, 0.9141414141414141, 0.75, 0.9090909090909091, 0.7, 0.9191919191919191, 0.8, 0.898989898989899] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSD', 0.45, 0.42424242424242425, 0.55, 0.5151515151515151, 0.55, 0.5202020202020201, 0.6, 0.5151515151515151, 0.45, 0.5909090909090909] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSDPCA', 0.75, 0.9292929292929293, 0.75, 0.8737373737373737, 0.8, 0.904040404040404, 0.8, 0.9393939393939393, 0.8, 0.898989898989899] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSD', 0.55, 0.6868686868686869, 0.3, 0.2777777777777778, 0.6, 0.4393939393939394, 0.55, 0.696969696969697, 0.45, 0.45959595959595956] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSDPCA', 0.8, 0.9494949494949495, 0.8, 0.9343434343434343, 0.75, 0.8737373737373737, 0.75, 0.9494949494949495, 0.7, 0.9393939393939393] <class 'list'> 11
#
# Gamma columns:
#  ['age', 'education', 'IQ', 'AB.F.gamma.a.FP1', 'AB.F.gamma.b.FP2', 'AB.F.gamma.c.F7', 'AB.F.gamma.d.F3', 'AB.F.gamma.e.Fz', 'AB.F.gamma.f.F4', 'AB.F.gamma.g.F8', 'AB.F.gamma.h.T3', 'AB.F.gamma.i.C3', 'AB.F.gamma.j.Cz', 'AB.F.gamma.k.C4', 'AB.F.gamma.l.T4', 'AB.F.gamma.m.T5', 'AB.F.gamma.n.P3', 'AB.F.gamma.o.Pz', 'AB.F.gamma.p.P4', 'AB.F.gamma.q.T6', 'AB.F.gamma.r.O1', 'AB.F.gamma.s.O2', 'Class']
# SVM accuracy: 0.4
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.18      0.25        11
#            1       0.40      0.67      0.50         9
#
#     accuracy                           0.40        20
#    macro avg       0.40      0.42      0.38        20
# weighted avg       0.40      0.40      0.36        20
#
# SVM AUC value: 0.3434343434343434
#
# SVM accuracy for PCA: 0.85
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        11
#            1       0.75      1.00      0.86         9
#
#     accuracy                           0.85        20
#    macro avg       0.88      0.86      0.85        20
# weighted avg       0.89      0.85      0.85        20
#
# SVM AUC value for PCA: 0.9494949494949495
# KNN accuracy: 0.55
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.55      0.57        11
#            1       0.50      0.56      0.53         9
#
#     accuracy                           0.55        20
#    macro avg       0.55      0.55      0.55        20
# weighted avg       0.55      0.55      0.55        20
#
# KNN AUC value: 0.47474747474747475
#
# KNN accuracy for PCA: 0.8
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.73      0.89      0.80         9
#
#     accuracy                           0.80        20
#    macro avg       0.81      0.81      0.80        20
# weighted avg       0.82      0.80      0.80        20
#
# KNN AUC value for PCA 0.9292929292929293
# Random Forest accuracy: 0.55
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.62      0.45      0.53        11
#            1       0.50      0.67      0.57         9
#
#     accuracy                           0.55        20
#    macro avg       0.56      0.56      0.55        20
# weighted avg       0.57      0.55      0.55        20
#
# Random Forest AUC value: 0.5202020202020201
#
# Random Forest accuracy for PCA: 0.8
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        11
#            1       0.78      0.78      0.78         9
#
#     accuracy                           0.80        20
#    macro avg       0.80      0.80      0.80        20
# weighted avg       0.80      0.80      0.80        20
#
# Random Forest AUC value for PCA: 0.9141414141414141
# Logistic Regression accuracy: 0.35
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.33      0.18      0.24        11
#            1       0.36      0.56      0.43         9
#
#     accuracy                           0.35        20
#    macro avg       0.35      0.37      0.34        20
# weighted avg       0.34      0.35      0.33        20
#
# Logistic Regression AUC value: 0.3535353535353535
#
# Logistic Regression accuracy for PCA: 0.85
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        11
#            1       0.75      1.00      0.86         9
#
#     accuracy                           0.85        20
#    macro avg       0.88      0.86      0.85        20
# weighted avg       0.89      0.85      0.85        20
#
# Logistic Regression AUC value for PCA 0.9494949494949495
# [0]	validation_0-logloss:0.77058
# [1]	validation_0-logloss:0.82518
# [2]	validation_0-logloss:0.83032
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# XGB accuracy: 0.3
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.29      0.18      0.22        11
#            1       0.31      0.44      0.36         9
#
#     accuracy                           0.30        20
#    macro avg       0.30      0.31      0.29        20
# weighted avg       0.30      0.30      0.29        20
#
# XGB AUC value: 0.2828282828282829
# [0]	validation_0-logloss:0.58276
# [1]	validation_0-logloss:0.50883
# [2]	validation_0-logloss:0.47436
# [3]	validation_0-logloss:0.44515
# [4]	validation_0-logloss:0.43323
# [5]	validation_0-logloss:0.41616
# [6]	validation_0-logloss:0.42387
# [7]	validation_0-logloss:0.41800
#
# XGB accuracy for PCA: 0.85
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        11
#            1       0.75      1.00      0.86         9
#
#     accuracy                           0.85        20
#    macro avg       0.88      0.86      0.85        20
# weighted avg       0.89      0.85      0.85        20
#
# XBG AUC for PCA: 0.9191919191919192
# [[8 3]
#  [0 9]]
# ['Anxiety+AEI_Delta_PSD', 0.6, 0.6363636363636364, 0.6, 0.6515151515151516, 0.3, 0.38888888888888895, 0.55, 0.6363636363636364, 0.6, 0.5151515151515151] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.75, 0.9494949494949494, 0.7, 0.8333333333333334, 0.6, 0.8888888888888888, 0.8, 0.9191919191919191, 0.8, 0.9191919191919191] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.35, 0.48484848484848486, 0.45, 0.4747474747474747, 0.4, 0.48484848484848486, 0.5, 0.6666666666666667, 0.55, 0.6313131313131313] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.75, 0.9191919191919191, 0.75, 0.8939393939393939, 0.75, 0.9191919191919191, 0.75, 0.9191919191919191, 0.7, 0.8989898989898989] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.65, 0.303030303030303, 0.3, 0.29292929292929293, 0.45, 0.601010101010101, 0.65, 0.7272727272727272, 0.5, 0.44949494949494956] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.75, 0.9191919191919191, 0.8, 0.9141414141414141, 0.75, 0.9090909090909091, 0.7, 0.9191919191919191, 0.8, 0.898989898989899] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSD', 0.45, 0.42424242424242425, 0.55, 0.5151515151515151, 0.55, 0.5202020202020201, 0.6, 0.5151515151515151, 0.45, 0.5909090909090909] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSDPCA', 0.75, 0.9292929292929293, 0.75, 0.8737373737373737, 0.8, 0.904040404040404, 0.8, 0.9393939393939393, 0.8, 0.898989898989899] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSD', 0.55, 0.6868686868686869, 0.3, 0.2777777777777778, 0.6, 0.4393939393939394, 0.55, 0.696969696969697, 0.45, 0.45959595959595956] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSDPCA', 0.8, 0.9494949494949495, 0.8, 0.9343434343434343, 0.75, 0.8737373737373737, 0.75, 0.9494949494949495, 0.7, 0.9393939393939393] <class 'list'> 11
# ['Anxiety+AEI_Gamma_PSD', 0.4, 0.3434343434343434, 0.55, 0.47474747474747475, 0.55, 0.5202020202020201, 0.35, 0.3535353535353535, 0.3, 0.2828282828282829] <class 'list'> 11
# ['Anxiety+AEI_Gamma_PSDPCA', 0.85, 0.9494949494949495, 0.8, 0.9292929292929293, 0.8, 0.9141414141414141, 0.85, 0.9494949494949495, 0.85, 0.9191919191919192] <class 'list'> 11
#
# All columns:
#  ['age', 'education', 'IQ', 'AB.A.delta.a.FP1', 'AB.A.delta.b.FP2', 'AB.A.delta.c.F7', 'AB.A.delta.d.F3', 'AB.A.delta.e.Fz', 'AB.A.delta.f.F4', 'AB.A.delta.g.F8', 'AB.A.delta.h.T3', 'AB.A.delta.i.C3', 'AB.A.delta.j.Cz', 'AB.A.delta.k.C4', 'AB.A.delta.l.T4', 'AB.A.delta.m.T5', 'AB.A.delta.n.P3', 'AB.A.delta.o.Pz', 'AB.A.delta.p.P4', 'AB.A.delta.q.T6', 'AB.A.delta.r.O1', 'AB.A.delta.s.O2', 'AB.B.theta.a.FP1', 'AB.B.theta.b.FP2', 'AB.B.theta.c.F7', 'AB.B.theta.d.F3', 'AB.B.theta.e.Fz', 'AB.B.theta.f.F4', 'AB.B.theta.g.F8', 'AB.B.theta.h.T3', 'AB.B.theta.i.C3', 'AB.B.theta.j.Cz', 'AB.B.theta.k.C4', 'AB.B.theta.l.T4', 'AB.B.theta.m.T5', 'AB.B.theta.n.P3', 'AB.B.theta.o.Pz', 'AB.B.theta.p.P4', 'AB.B.theta.q.T6', 'AB.B.theta.r.O1', 'AB.B.theta.s.O2', 'AB.C.alpha.a.FP1', 'AB.C.alpha.b.FP2', 'AB.C.alpha.c.F7', 'AB.C.alpha.d.F3', 'AB.C.alpha.e.Fz', 'AB.C.alpha.f.F4', 'AB.C.alpha.g.F8', 'AB.C.alpha.h.T3', 'AB.C.alpha.i.C3', 'AB.C.alpha.j.Cz', 'AB.C.alpha.k.C4', 'AB.C.alpha.l.T4', 'AB.C.alpha.m.T5', 'AB.C.alpha.n.P3', 'AB.C.alpha.o.Pz', 'AB.C.alpha.p.P4', 'AB.C.alpha.q.T6', 'AB.C.alpha.r.O1', 'AB.C.alpha.s.O2', 'AB.D.beta.a.FP1', 'AB.D.beta.b.FP2', 'AB.D.beta.c.F7', 'AB.D.beta.d.F3', 'AB.D.beta.e.Fz', 'AB.D.beta.f.F4', 'AB.D.beta.g.F8', 'AB.D.beta.h.T3', 'AB.D.beta.i.C3', 'AB.D.beta.j.Cz', 'AB.D.beta.k.C4', 'AB.D.beta.l.T4', 'AB.D.beta.m.T5', 'AB.D.beta.n.P3', 'AB.D.beta.o.Pz', 'AB.D.beta.p.P4', 'AB.D.beta.q.T6', 'AB.D.beta.r.O1', 'AB.D.beta.s.O2', 'AB.E.highbeta.a.FP1', 'AB.E.highbeta.b.FP2', 'AB.E.highbeta.c.F7', 'AB.E.highbeta.d.F3', 'AB.E.highbeta.e.Fz', 'AB.E.highbeta.f.F4', 'AB.E.highbeta.g.F8', 'AB.E.highbeta.h.T3', 'AB.E.highbeta.i.C3', 'AB.E.highbeta.j.Cz', 'AB.E.highbeta.k.C4', 'AB.E.highbeta.l.T4', 'AB.E.highbeta.m.T5', 'AB.E.highbeta.n.P3', 'AB.E.highbeta.o.Pz', 'AB.E.highbeta.p.P4', 'AB.E.highbeta.q.T6', 'AB.E.highbeta.r.O1', 'AB.E.highbeta.s.O2', 'AB.F.gamma.a.FP1', 'AB.F.gamma.b.FP2', 'AB.F.gamma.c.F7', 'AB.F.gamma.d.F3', 'AB.F.gamma.e.Fz', 'AB.F.gamma.f.F4', 'AB.F.gamma.g.F8', 'AB.F.gamma.h.T3', 'AB.F.gamma.i.C3', 'AB.F.gamma.j.Cz', 'AB.F.gamma.k.C4', 'AB.F.gamma.l.T4', 'AB.F.gamma.m.T5', 'AB.F.gamma.n.P3', 'AB.F.gamma.o.Pz', 'AB.F.gamma.p.P4', 'AB.F.gamma.q.T6', 'AB.F.gamma.r.O1', 'AB.F.gamma.s.O2', 'Class']
# SVM accuracy: 0.6
# SVM classification report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.55      0.60        11
#            1       0.55      0.67      0.60         9
#
#     accuracy                           0.60        20
#    macro avg       0.61      0.61      0.60        20
# weighted avg       0.61      0.60      0.60        20
#
# SVM AUC value: 0.5858585858585859
#
# SVM accuracy for PCA: 0.75
# SVM classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71        11
#            1       0.64      1.00      0.78         9
#
#     accuracy                           0.75        20
#    macro avg       0.82      0.77      0.74        20
# weighted avg       0.84      0.75      0.74        20
#
# SVM AUC value for PCA: 0.9595959595959596
# KNN accuracy: 0.6
# KNN classification report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67        11
#            1       0.57      0.44      0.50         9
#
#     accuracy                           0.60        20
#    macro avg       0.59      0.59      0.58        20
# weighted avg       0.60      0.60      0.59        20
#
# KNN AUC value: 0.5656565656565657
#
# KNN accuracy for PCA: 0.65
# KNN classification report for PCA
#                precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70        11
#            1       0.62      0.56      0.59         9
#
#     accuracy                           0.65        20
#    macro avg       0.65      0.64      0.64        20
# weighted avg       0.65      0.65      0.65        20
#
# KNN AUC value for PCA 0.7777777777777777
# Random Forest accuracy: 0.45
# Random Forest classification report
#                precision    recall  f1-score   support
#
#            0       0.50      0.36      0.42        11
#            1       0.42      0.56      0.48         9
#
#     accuracy                           0.45        20
#    macro avg       0.46      0.46      0.45        20
# weighted avg       0.46      0.45      0.45        20
#
# Random Forest AUC value: 0.36363636363636365
#
# Random Forest accuracy for PCA: 0.65
# Random Forest classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.83      0.45      0.59        11
#            1       0.57      0.89      0.70         9
#
#     accuracy                           0.65        20
#    macro avg       0.70      0.67      0.64        20
# weighted avg       0.72      0.65      0.64        20
#
# Random Forest AUC value for PCA: 0.8232323232323232
# Logistic Regression accuracy: 0.55
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61        11
#            1       0.50      0.44      0.47         9
#
#     accuracy                           0.55        20
#    macro avg       0.54      0.54      0.54        20
# weighted avg       0.55      0.55      0.55        20
#
# Logistic Regression AUC value: 0.5959595959595959
#
# Logistic Regression accuracy for PCA: 0.7
# Logistic Regression classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.86      0.55      0.67        11
#            1       0.62      0.89      0.73         9
#
#     accuracy                           0.70        20
#    macro avg       0.74      0.72      0.70        20
# weighted avg       0.75      0.70      0.69        20
#
# Logistic Regression AUC value for PCA 0.9393939393939393
# /home/novo/miniforge3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0]	validation_0-logloss:0.73937
# [1]	validation_0-logloss:0.77185
# XGB accuracy: 0.5
# XGB Classification report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.18      0.29        11
#            1       0.47      0.89      0.62         9
#
#     accuracy                           0.50        20
#    macro avg       0.57      0.54      0.45        20
# weighted avg       0.58      0.50      0.43        20
#
# XGB AUC value: 0.40404040404040403
# [0]	validation_0-logloss:0.66569
# [1]	validation_0-logloss:0.60467
# [2]	validation_0-logloss:0.60266
# [3]	validation_0-logloss:0.54955
# [4]	validation_0-logloss:0.55799
# [5]	validation_0-logloss:0.56077
#
# XGB accuracy for PCA: 0.75
# XGB classification report for PCA:
#                precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        11
#            1       0.67      0.89      0.76         9
#
#     accuracy                           0.75        20
#    macro avg       0.77      0.76      0.75        20
# weighted avg       0.78      0.75      0.75        20
#
# XBG AUC for PCA: 0.8535353535353535
# [[7 4]
#  [1 8]]
# ['Anxiety+AEI_Delta_PSD', 0.6, 0.6363636363636364, 0.6, 0.6515151515151516, 0.3, 0.38888888888888895, 0.55, 0.6363636363636364, 0.6, 0.5151515151515151] <class 'list'> 11
# ['Anxiety+AEI_Delta_PSDPCA', 0.75, 0.9494949494949494, 0.7, 0.8333333333333334, 0.6, 0.8888888888888888, 0.8, 0.9191919191919191, 0.8, 0.9191919191919191] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSD', 0.35, 0.48484848484848486, 0.45, 0.4747474747474747, 0.4, 0.48484848484848486, 0.5, 0.6666666666666667, 0.55, 0.6313131313131313] <class 'list'> 11
# ['Anxiety+AEI_Theta_PSDPCA', 0.75, 0.9191919191919191, 0.75, 0.8939393939393939, 0.75, 0.9191919191919191, 0.75, 0.9191919191919191, 0.7, 0.8989898989898989] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSD', 0.65, 0.303030303030303, 0.3, 0.29292929292929293, 0.45, 0.601010101010101, 0.65, 0.7272727272727272, 0.5, 0.44949494949494956] <class 'list'> 11
# ['Anxiety+AEI_Alpha_PSDPCA', 0.75, 0.9191919191919191, 0.8, 0.9141414141414141, 0.75, 0.9090909090909091, 0.7, 0.9191919191919191, 0.8, 0.898989898989899] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSD', 0.45, 0.42424242424242425, 0.55, 0.5151515151515151, 0.55, 0.5202020202020201, 0.6, 0.5151515151515151, 0.45, 0.5909090909090909] <class 'list'> 11
# ['Anxiety+AEI_Beta_PSDPCA', 0.75, 0.9292929292929293, 0.75, 0.8737373737373737, 0.8, 0.904040404040404, 0.8, 0.9393939393939393, 0.8, 0.898989898989899] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSD', 0.55, 0.6868686868686869, 0.3, 0.2777777777777778, 0.6, 0.4393939393939394, 0.55, 0.696969696969697, 0.45, 0.45959595959595956] <class 'list'> 11
# ['Anxiety+AEI_HighBeta_PSDPCA', 0.8, 0.9494949494949495, 0.8, 0.9343434343434343, 0.75, 0.8737373737373737, 0.75, 0.9494949494949495, 0.7, 0.9393939393939393] <class 'list'> 11
# ['Anxiety+AEI_Gamma_PSD', 0.4, 0.3434343434343434, 0.55, 0.47474747474747475, 0.55, 0.5202020202020201, 0.35, 0.3535353535353535, 0.3, 0.2828282828282829] <class 'list'> 11
# ['Anxiety+AEI_Gamma_PSDPCA', 0.85, 0.9494949494949495, 0.8, 0.9292929292929293, 0.8, 0.9141414141414141, 0.85, 0.9494949494949495, 0.85, 0.9191919191919192] <class 'list'> 11
# ['Anxiety+AEI_All_PSD', 0.6, 0.5858585858585859, 0.6, 0.5656565656565657, 0.45, 0.36363636363636365, 0.55, 0.5959595959595959, 0.5, 0.40404040404040403] <class 'list'> 11
# ['Anxiety+AEI_All_PSDPCA', 0.75, 0.9595959595959596, 0.65, 0.7777777777777777, 0.65, 0.8232323232323232, 0.7, 0.9393939393939393, 0.75, 0.8535353535353535] <class 'list'> 11
